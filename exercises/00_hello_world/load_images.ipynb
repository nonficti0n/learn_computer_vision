# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
# %matplotlib inline

# %%
# Load an color image in grayscale
img = cv2.imread('boat.jpg',0)
h,w = img.shape[:2]
print(img.shape)
# Out:
# (900, 1600)

# %%
# Show image
plt.imshow(img,cmap='gray')
plt.show()

# %%
# Show intensity of row of image
row=500;

fig, ax = plt.subplots()
ax.plot(np.arange(len(img[row,:])), img[row,:])

ax.set(xlabel='X', ylabel='Y',
       title='Intensity in row '+str(row))
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
# Cropping image
img2=img[100:400,100:400]
plt.imshow(img2,cmap='gray')
plt.show()

# %%
# Load color image
imgc = cv2.imread('boat.jpg',1)[:,:,::-1]
plt.imshow(imgc)
plt.show()

imgc.shape
# Out:
# (900, 1600, 3)

# %%
img_red=imgc[:,:,0]
img_green=imgc[:,:,1]
img_blue=imgc[:,:,2]
plt.imshow(img_red,cmap='gray')
plt.show()
plt.imshow(img_green,cmap='gray')
plt.show()
plt.imshow(img_blue,cmap='gray')
plt.show()

# %%
# Flip image
imgc_flip=np.flip(imgc,axis=1)
plt.imshow(imgc_flip)
plt.show()

# %%
# Average of images
imgc_sum=(imgc.astype(float)+imgc_flip.astype(float))/255/2
plt.imshow(imgc_sum)
plt.show()

# Blending of images
imgc_blend=(imgc.astype(float)*0.75+imgc_flip.astype(float)*0.25)/255
plt.imshow(imgc_blend)
plt.show()

# %%
# Difference of images
img_flip=np.flip(img,axis=1)
img_diff=np.abs((img.astype(float)-img_flip.astype(float))/255)
plt.imshow(img_diff,cmap='gray')
plt.show()

img_diff2=cv2.subtract(img,img_flip)
plt.imshow(img_diff,cmap='gray')
plt.show()

img_diff3=cv2.subtract(img_diff.astype(np.uint8),img_diff2)
plt.imshow(img_diff3,cmap='gray')
plt.show()
